# %% [markdown]
# # Prepare Chicago Crime Data for a GitHub Repository

# %% [markdown]
# - Original Notebook Source: https://github.com/coding-dojo-data-science/preparing-chicago-crime-data
# - Updated 11/17/22

# %% [markdown]
# >- This notebook will process a "Crimes - 2001 to Preset.csv" crime file in your Downloads folder and save it as smaller .csv's in a new "Data/Chicago/" folder inside this notebook's folder/repo.

# %% [markdown]
# # INSTRUCTIONS

# %% [markdown]
# - 1) Go to the Chicago Data Portal's page for ["Crimes - 2001 to Preset"](https://data.cityofchicago.org/Public-Safety/Crimes-2001-to-Present/ijzp-q8t2).
#
# - 2) Click on the Export button on the top right and select CSV.
#     - Save the file to your Downloads folder instead of your repository. **The file is too big for a repository.**
#
#
#
# - 3) Wait for the full file to download.
#     - It is very large (over >1.7GB and may take several minutes to fully download.)
#
#
# - 4) Once the download is complete, change `RAW_FILE` variable below to match the filepath to the downloaded file.

# %% [markdown]
# ## 🚨 Set the correct `RAW_FILE` path

# %% [markdown]
# - The cell below will attempt to check your Downloads folder for any file with a name that contains "Crimes_-_2001_to_Present".
#     - If you know the file path already, you can skip the next cell and just manually set the RAW_FILE variable in the following code cell.

# %%
## Run the cell below to attempt to programmatically find your crime file
import os,glob

## Getting the home folder from environment variables
home_folder = os.environ['HOME']
# print("- Your Home Folder is: " + home_folder)

## Check for downloads folder
if 'Downloads' in os.listdir(home_folder):
    
    
    # Print the Downloads folder path
    dl_folder = os.path.abspath(os.path.join(home_folder,'Downloads'))
    print(f"- Your Downloads folder is '{dl_folder}/'\n")
    
    ## checking for crime files using glob
    crime_files = sorted(glob.glob(dl_folder+'/**/Crimes_-_2001_to_Present*',recursive=True))
    
    # If more than 
    if len(crime_files)==1:
        RAW_FILE = crime_files[0]
        
    elif len(crime_files)>1:
        print('[i] The following files were found:')
        
        for i, fname in enumerate(crime_files):
            print(f"\tcrime_files[{i}] = '{fname}'")
        print(f'\n- Please fill in the RAW_FILE variable in the code cell below with the correct filepath.')

else:
    print(f'[!] Could not programmatically find your downloads folder.')
    print('- Try using Finder (on Mac) or File Explorer (Windows) to navigate to your Downloads folder.')
# Out:
# - Your Downloads folder is '/Users/whitefreeze/Downloads/'

# %% [markdown]
# <span style="color:red"> **IF THE CODE ABOVE DID NOT FIND YOUR DOWNLOADED FILE, UNCOMMENT AND CHANGE THE `"YOUR FILEPATH HERE"` VARIABLE ONLY IN THE CELL BELOW**

# %%
## (Required) MAKE SURE TO CHANGE THIS VARIABLE TO MATCH YOUR LOCAL FILE NAME
##RAW_FILE = r"YOUR FILEPATH HERE")

# %% [markdown]
# <span style="color:red"> **DO NOT CHANGE ANYTHING IN THE CELL BELOW**

# %%
## DO NOT CHANGE THIS CELL
if RAW_FILE == r"YOUR FILEPATH HERE":
	raise Exception("You must update the RAW_FILE variable in the previous cell to match your local filepath.")
	
RAW_FILE
# Out:
# '/Users/whitefreeze/Downloads/Crimes_-_2001_to_Present.csv'

# %%
## (Optional) SET THE FOLDER FOR FINAL FILES
OUTPUT_FOLDER = 'Data/Chicago/'
os.makedirs(OUTPUT_FOLDER, exist_ok=True)

# %% [markdown]
# # 🔄 Full Workflow

# %% [markdown]
# - Now that your RAW_FILE variable is set either:
#     - On the toolbar, click on the Kernel menu > "Restart and Run All".
#     - OR click on this cell first, then on the toolbar click on the "Cell" menu > "Run All Below"

# %%
import pandas as pd

chicago_full = pd.read_csv(RAW_FILE)
chicago_full
# Out:
#                ID Case Number                    Date                   Block  \
# 0        11646166    JC213529  09/01/2018 12:01:00 AM   082XX S INGLESIDE AVE
# 1        11645836    JC212333  05/01/2016 12:25:00 AM     055XX S ROCKWELL ST
# 2        11243268    JB167760  01/01/2017 12:01:00 AM        047XX N CLARK ST
# 3         1896258     G749215  12/15/2001 02:00:00 AM        011XX N STATE ST
# 4        11645527    JC212744  02/02/2015 10:00:00 AM      069XX W ARCHER AVE
# ...           ...         ...                     ...                     ...
# 7863370  13128007    JG325985  06/21/2023 08:00:00 PM  031XX N CALIFORNIA AVE
# 7863371  13128066    JG325838  06/06/2023 03:42:00 PM    018XX N LOCKWOOD AVE
# 7863372  13129823    JG328250  06/28/2023 06:00:00 PM      059XX S KEELER AVE
# 7863373  13128324    JG326502  05/13/2023 12:00:00 PM       020XX W CERMAK RD
# 7863374  13129172    JG327619  06/20/2023 04:00:00 AM   028XX N MAPLEWOOD AVE
#
#          IUCR                Primary Type  \
# 0        0810                       THEFT
# 1        1153          DECEPTIVE PRACTICE
# 2        1562                 SEX OFFENSE
# 3        0460                     BATTERY
# 4        1153          DECEPTIVE PRACTICE
# ...       ...                         ...
# 7863370  1320             CRIMINAL DAMAGE
# 7863371  1752  OFFENSE INVOLVING CHILDREN
# 7863372  0810                       THEFT
# 7863373  1120          DECEPTIVE PRACTICE
# 7863374  0460                     BATTERY
#
#                                                Description  \
# 0                                                OVER $500
# 1                      FINANCIAL IDENTITY THEFT OVER $ 300
# 2                                AGG CRIMINAL SEXUAL ABUSE
# 3                                                   SIMPLE
# 4                      FINANCIAL IDENTITY THEFT OVER $ 300
# ...                                                    ...
# 7863370                                         TO VEHICLE
# 7863371  AGGRAVATED CRIMINAL SEXUAL ABUSE BY FAMILY MEMBER
# 7863372                                          OVER $500
# 7863373                                            FORGERY
# 7863374                                             SIMPLE
#
#         Location Description  Arrest  Domestic  ...  Ward  Community Area  \
# 0                  RESIDENCE   False      True  ...   8.0            44.0
# 1                        NaN   False     False  ...  15.0            63.0
# 2                  APARTMENT   False     False  ...  47.0             3.0
# 3                     STREET   False     False  ...   NaN             NaN
# 4                      OTHER   False     False  ...  23.0            56.0
# ...                      ...     ...       ...  ...   ...             ...
# 7863370               STREET   False     False  ...  35.0            21.0
# 7863371            APARTMENT   False     False  ...  37.0            25.0
# 7863372               STREET   False     False  ...  13.0            65.0
# 7863373    CURRENCY EXCHANGE   False     False  ...  25.0            31.0
# 7863374            RESIDENCE   False      True  ...  35.0            21.0
#
#          FBI Code  X Coordinate Y Coordinate  Year              Updated On  \
# 0              06           NaN          NaN  2018  04/06/2019 04:04:43 PM
# 1              11           NaN          NaN  2016  04/06/2019 04:04:43 PM
# 2              17           NaN          NaN  2017  09/13/2018 03:56:52 PM
# 3             08B           NaN          NaN  2001  08/17/2015 03:03:40 PM
# 4              11           NaN          NaN  2015  04/06/2019 04:04:43 PM
# ...           ...           ...          ...   ...                     ...
# 7863370        14     1157169.0    1920611.0  2023  08/05/2023 04:45:54 PM
# 7863371        17     1140792.0    1911954.0  2023  08/05/2023 04:45:54 PM
# 7863372        06     1149387.0    1864869.0  2023  08/05/2023 04:45:54 PM
# 7863373        10     1163211.0    1889404.0  2023  08/05/2023 04:45:54 PM
# 7863374       08B     1158868.0    1918755.0  2023  08/05/2023 04:45:54 PM
#
#           Latitude  Longitude                       Location
# 0              NaN        NaN                            NaN
# 1              NaN        NaN                            NaN
# 2              NaN        NaN                            NaN
# 3              NaN        NaN                            NaN
# 4              NaN        NaN                            NaN
# ...            ...        ...                            ...
# 7863370  41.937926 -87.697782  (41.937925817, -87.697782474)
# 7863371  41.914487 -87.758185  (41.914487492, -87.758185241)
# 7863372  41.785118 -87.727828  (41.785117789, -87.727827896)
# 7863373  41.852166 -87.676455   (41.85216632, -87.676455032)
# 7863374  41.932798 -87.691589  (41.932798095, -87.691589364)
#
# [7863375 rows x 22 columns]

# %%
# this cell can take up to 1 min to run
date_format = "%m/%d/%Y %H:%M:%S %p"

chicago_full['Datetime'] = pd.to_datetime(chicago_full['Date'], format=date_format)
chicago_full = chicago_full.sort_values('Datetime')
chicago_full
# Out:
#                ID Case Number                    Date                  Block  \
# 2215391   1314713     G001044  01/01/2001 01:00:00 PM     017XX W AUGUSTA BV
# 2214418   1311732     G001071  01/01/2001 01:00:00 PM    013XX N BOSWORTH AV
# 2419244   1584605     G351833  01/01/2001 01:00:00 AM    024XX W CORTLAND ST
# 2216818   1317937     G001149  01/01/2001 01:00:00 AM          024XX E 73 ST
# 2221476   1326041     G021012  01/01/2001 01:00:00 AM  048XX W HUTCHINSON ST
# ...           ...         ...                     ...                    ...
# 302953   13164175    JG369072  08/04/2023 12:55:00 PM     063XX S KEDZIE AVE
# 304941   13163716    JG368446  08/04/2023 12:55:00 AM       001XX W HURON ST
# 303727   13168014    JG373722  08/04/2023 12:56:00 PM       0000X N STATE ST
# 306239   13164201    JG369076  08/04/2023 12:56:00 PM      021XX N MAJOR AVE
# 307219   13165971    JG368476  08/04/2023 12:57:00 AM      107XX S EWING AVE
#
#          IUCR            Primary Type                     Description  \
# 2215391  0520                 ASSAULT  AGGRAVATED:KNIFE/CUTTING INSTR
# 2214418  2851  PUBLIC PEACE VIOLATION                    ARSON THREAT
# 2419244  2825           OTHER OFFENSE         HARASSMENT BY TELEPHONE
# 2216818  0460                 BATTERY                          SIMPLE
# 2221476  0460                 BATTERY                          SIMPLE
# ...       ...                     ...                             ...
# 302953   031A                 ROBBERY                 ARMED - HANDGUN
# 304941   1330       CRIMINAL TRESPASS                         TO LAND
# 303727   0860                   THEFT                    RETAIL THEFT
# 306239   4387           OTHER OFFENSE     VIOLATE ORDER OF PROTECTION
# 307219   0560                 ASSAULT                          SIMPLE
#
#             Location Description  Arrest  Domestic  ...  Community Area  \
# 2215391                RESIDENCE    True      True  ...             NaN
# 2214418                RESIDENCE   False     False  ...             NaN
# 2419244                RESIDENCE   False     False  ...             NaN
# 2216818  RESIDENCE PORCH/HALLWAY   False     False  ...             NaN
# 2221476                RESIDENCE   False     False  ...             NaN
# ...                          ...     ...       ...  ...             ...
# 302953                DRUG STORE   False     False  ...            66.0
# 304941             HOTEL / MOTEL    True     False  ...             8.0
# 303727          DEPARTMENT STORE   False     False  ...            32.0
# 306239                    STREET   False      True  ...            19.0
# 307219        GROCERY FOOD STORE   False     False  ...            52.0
#
#          FBI Code  X Coordinate  Y Coordinate  Year              Updated On  \
# 2215391       04A     1164232.0     1906669.0  2001  08/17/2015 03:03:40 PM
# 2214418        26     1165804.0     1908952.0  2001  08/17/2015 03:03:40 PM
# 2419244        26     1159701.0     1912508.0  2001  08/17/2015 03:03:40 PM
# 2216818       08B     1193629.0     1856985.0  2001  08/17/2015 03:03:40 PM
# 2221476       08B     1143134.0     1927772.0  2001  08/17/2015 03:03:40 PM
# ...           ...           ...           ...   ...                     ...
# 302953         03     1156143.0     1862448.0  2023  08/11/2023 10:00:52 PM
# 304941         26           NaN           NaN  2023  08/11/2023 10:00:52 PM
# 303727         06     1176364.0     1900524.0  2023  08/11/2023 10:00:52 PM
# 306239         26     1138053.0     1913363.0  2023  08/11/2023 10:00:52 PM
# 307219        08A           NaN           NaN  2023  08/11/2023 10:00:52 PM
#
#           Latitude  Longitude                       Location  \
# 2215391  41.899521 -87.672220  (41.899521453, -87.672219588)
# 2214418  41.905753 -87.666380  (41.905752775, -87.666380466)
# 2419244  41.915639 -87.688701  (41.915638736, -87.688700749)
# 2216818  41.762514 -87.565877  (41.762514064, -87.565876899)
# 2221476  41.957850 -87.749185  (41.957850185, -87.749184996)
# ...            ...        ...                            ...
# 302953   41.778341 -87.703122  (41.778340981, -87.703122242)
# 304941         NaN        NaN                            NaN
# 303727   41.882394 -87.627845  (41.882394062, -87.627844798)
# 306239   41.918404 -87.768214  (41.918403912, -87.768213964)
# 307219         NaN        NaN                            NaN
#
#                    Datetime
# 2215391 2001-01-01 01:00:00
# 2214418 2001-01-01 01:00:00
# 2419244 2001-01-01 01:00:00
# 2216818 2001-01-01 01:00:00
# 2221476 2001-01-01 01:00:00
# ...                     ...
# 302953  2023-08-04 12:55:00
# 304941  2023-08-04 12:55:00
# 303727  2023-08-04 12:56:00
# 306239  2023-08-04 12:56:00
# 307219  2023-08-04 12:57:00
#
# [7863375 rows x 23 columns]

# %% [markdown]
# ## Separate the Full Dataset by Years

# %%
chicago_full['Datetime'].dt.year
# Out:
# 2215391    2001
# 2214418    2001
# 2419244    2001
# 2216818    2001
# 2221476    2001
#            ...
# 302953     2023
# 304941     2023
# 303727     2023
# 306239     2023
# 307219     2023
# Name: Datetime, Length: 7863375, dtype: int64

# %%
# save the years for every crime
chicago_full["Year"] = chicago_full['Datetime'].dt.year.astype(str)
chicago_full["Year"].value_counts()
# Out:
# 2002    486807
# 2001    485886
# 2003    475984
# 2004    469421
# 2005    453772
# 2006    448179
# 2007    437087
# 2008    427169
# 2009    392825
# 2010    370505
# 2011    351978
# 2012    336275
# 2013    307479
# 2014    275752
# 2016    269816
# 2017    269100
# 2018    268820
# 2015    264780
# 2019    261297
# 2022    238766
# 2020    212186
# 2021    208779
# 2023    150712
# Name: Year, dtype: int64

# %%
## Dropping unneeded columns to reduce file size
drop_cols = ["X Coordinate","Y Coordinate", "Community Area","FBI Code",
             "Case Number","Updated On",'Block','Location','IUCR']

# %%
# save final df
chicago_final = chicago_full.drop(columns=drop_cols)
chicago_final = chicago_final.set_index('Datetime')
chicago_final
# Out:
#                            ID                    Date            Primary Type  \
# Datetime
# 2001-01-01 01:00:00   1314713  01/01/2001 01:00:00 PM                 ASSAULT
# 2001-01-01 01:00:00   1311732  01/01/2001 01:00:00 PM  PUBLIC PEACE VIOLATION
# 2001-01-01 01:00:00   1584605  01/01/2001 01:00:00 AM           OTHER OFFENSE
# 2001-01-01 01:00:00   1317937  01/01/2001 01:00:00 AM                 BATTERY
# 2001-01-01 01:00:00   1326041  01/01/2001 01:00:00 AM                 BATTERY
# ...                       ...                     ...                     ...
# 2023-08-04 12:55:00  13164175  08/04/2023 12:55:00 PM                 ROBBERY
# 2023-08-04 12:55:00  13163716  08/04/2023 12:55:00 AM       CRIMINAL TRESPASS
# 2023-08-04 12:56:00  13168014  08/04/2023 12:56:00 PM                   THEFT
# 2023-08-04 12:56:00  13164201  08/04/2023 12:56:00 PM           OTHER OFFENSE
# 2023-08-04 12:57:00  13165971  08/04/2023 12:57:00 AM                 ASSAULT
#
#                                         Description     Location Description  \
# Datetime
# 2001-01-01 01:00:00  AGGRAVATED:KNIFE/CUTTING INSTR                RESIDENCE
# 2001-01-01 01:00:00                    ARSON THREAT                RESIDENCE
# 2001-01-01 01:00:00         HARASSMENT BY TELEPHONE                RESIDENCE
# 2001-01-01 01:00:00                          SIMPLE  RESIDENCE PORCH/HALLWAY
# 2001-01-01 01:00:00                          SIMPLE                RESIDENCE
# ...                                             ...                      ...
# 2023-08-04 12:55:00                 ARMED - HANDGUN               DRUG STORE
# 2023-08-04 12:55:00                         TO LAND            HOTEL / MOTEL
# 2023-08-04 12:56:00                    RETAIL THEFT         DEPARTMENT STORE
# 2023-08-04 12:56:00     VIOLATE ORDER OF PROTECTION                   STREET
# 2023-08-04 12:57:00                          SIMPLE       GROCERY FOOD STORE
#
#                      Arrest  Domestic  Beat  District  Ward  Year   Latitude  \
# Datetime
# 2001-01-01 01:00:00    True      True  1322      12.0   NaN  2001  41.899521
# 2001-01-01 01:00:00   False     False  1433      14.0   NaN  2001  41.905753
# 2001-01-01 01:00:00   False     False  1434      14.0   NaN  2001  41.915639
# 2001-01-01 01:00:00   False     False   334       3.0   NaN  2001  41.762514
# 2001-01-01 01:00:00   False     False  1624      16.0   NaN  2001  41.957850
# ...                     ...       ...   ...       ...   ...   ...        ...
# 2023-08-04 12:55:00   False     False   823       8.0  14.0  2023  41.778341
# 2023-08-04 12:55:00    True     False  1832      18.0  42.0  2023        NaN
# 2023-08-04 12:56:00   False     False   112       1.0  34.0  2023  41.882394
# 2023-08-04 12:56:00   False      True  2515      25.0  36.0  2023  41.918404
# 2023-08-04 12:57:00   False     False   432       4.0  10.0  2023        NaN
#
#                      Longitude
# Datetime
# 2001-01-01 01:00:00 -87.672220
# 2001-01-01 01:00:00 -87.666380
# 2001-01-01 01:00:00 -87.688701
# 2001-01-01 01:00:00 -87.565877
# 2001-01-01 01:00:00 -87.749185
# ...                        ...
# 2023-08-04 12:55:00 -87.703122
# 2023-08-04 12:55:00        NaN
# 2023-08-04 12:56:00 -87.627845
# 2023-08-04 12:56:00 -87.768214
# 2023-08-04 12:57:00        NaN
#
# [7863375 rows x 13 columns]

# %%
# unique # of year bins
year_bins = chicago_final['Year'].astype(str).unique()
year_bins
# Out:
# array(['2001', '2002', '2003', '2004', '2005', '2006', '2007', '2008',
#        '2009', '2010', '2011', '2012', '2013', '2014', '2015', '2016',
#        '2017', '2018', '2019', '2020', '2021', '2022', '2023'],
#       dtype=object)

# %%
FINAL_DROP = ['Year']

# %%
## set save location 

os.makedirs(OUTPUT_FOLDER, exist_ok=True)
print(f"[i] Saving .csv's to {OUTPUT_FOLDER}")
## loop through years
for year in year_bins:
    
    ## save temp slices of dfs to save.
    temp_df = chicago_final.loc[year]
    temp_df = temp_df.sort_index()
    temp_df = temp_df.reset_index(drop=True)
    temp_df = temp_df.drop(columns=FINAL_DROP)

    # save as csv to output folder
    fname_temp = f"{OUTPUT_FOLDER}Chicago-Crime_{year}.csv"#.gz
    temp_df.to_csv(fname_temp,index=False)

    print(f"- Succesfully saved {fname_temp}")
# Out:
# [i] Saving .csv's to Data/Chicago/
# - Succesfully saved Data/Chicago/Chicago-Crime_2001.csv
# - Succesfully saved Data/Chicago/Chicago-Crime_2002.csv
# - Succesfully saved Data/Chicago/Chicago-Crime_2003.csv
# - Succesfully saved Data/Chicago/Chicago-Crime_2004.csv
# - Succesfully saved Data/Chicago/Chicago-Crime_2005.csv
# - Succesfully saved Data/Chicago/Chicago-Crime_2006.csv
# - Succesfully saved Data/Chicago/Chicago-Crime_2007.csv
# - Succesfully saved Data/Chicago/Chicago-Crime_2008.csv
# - Succesfully saved Data/Chicago/Chicago-Crime_2009.csv
# - Succesfully saved Data/Chicago/Chicago-Crime_2010.csv
# - Succesfully saved Data/Chicago/Chicago-Crime_2011.csv
# - Succesfully saved Data/Chicago/Chicago-Crime_2012.csv
# - Succesfully saved Data/Chicago/Chicago-Crime_2013.csv
# - Succesfully saved Data/Chicago/Chicago-Crime_2014.csv
# - Succesfully saved Data/Chicago/Chicago-Crime_2015.csv
# - Succesfully saved Data/Chicago/Chicago-Crime_2016.csv
# - Succesfully saved Data/Chicago/Chicago-Crime_2017.csv
# - Succesfully saved Data/Chicago/Chicago-Crime_2018.csv
# - Succesfully saved Data/Chicago/Chicago-Crime_2019.csv
# - Succesfully saved Data/Chicago/Chicago-Crime_2020.csv
# - Succesfully saved Data/Chicago/Chicago-Crime_2021.csv
# - Succesfully saved Data/Chicago/Chicago-Crime_2022.csv
# - Succesfully saved Data/Chicago/Chicago-Crime_2023.csv

# %%
saved_files = sorted(glob.glob(OUTPUT_FOLDER+'*.*csv'))
saved_files
# Out:
# ['Data/Chicago/Chicago-Crime_2001.csv',
#  'Data/Chicago/Chicago-Crime_2002.csv',
#  'Data/Chicago/Chicago-Crime_2003.csv',
#  'Data/Chicago/Chicago-Crime_2004.csv',
#  'Data/Chicago/Chicago-Crime_2005.csv',
#  'Data/Chicago/Chicago-Crime_2006.csv',
#  'Data/Chicago/Chicago-Crime_2007.csv',
#  'Data/Chicago/Chicago-Crime_2008.csv',
#  'Data/Chicago/Chicago-Crime_2009.csv',
#  'Data/Chicago/Chicago-Crime_2010.csv',
#  'Data/Chicago/Chicago-Crime_2011.csv',
#  'Data/Chicago/Chicago-Crime_2012.csv',
#  'Data/Chicago/Chicago-Crime_2013.csv',
#  'Data/Chicago/Chicago-Crime_2014.csv',
#  'Data/Chicago/Chicago-Crime_2015.csv',
#  'Data/Chicago/Chicago-Crime_2016.csv',
#  'Data/Chicago/Chicago-Crime_2017.csv',
#  'Data/Chicago/Chicago-Crime_2018.csv',
#  'Data/Chicago/Chicago-Crime_2019.csv',
#  'Data/Chicago/Chicago-Crime_2020.csv',
#  'Data/Chicago/Chicago-Crime_2021.csv',
#  'Data/Chicago/Chicago-Crime_2022.csv',
#  'Data/Chicago/Chicago-Crime_2023.csv']

# %%
## create a README.txt for the zip files
readme = """Source URL: 
- https://data.cityofchicago.org/Public-Safety/Crimes-2001-to-Present/ijzp-q8t2
- Filtered for years 2000-Present.

Downloaded 07/18/2022
- Files are split into 1 year per file.

EXAMPLE USAGE:
>> import glob
>> import pandas as pd
>> folder = "Data/Chicago/"
>> crime_files = sorted(glob.glob(folder+"*.csv"))
>> df = pd.concat([pd.read_csv(f) for f in crime_files])
"""
print(readme)


with open(f"{OUTPUT_FOLDER}README.txt",'w') as f:
    f.write(readme)
# Out:
# Source URL:
# - https://data.cityofchicago.org/Public-Safety/Crimes-2001-to-Present/ijzp-q8t2
# - Filtered for years 2000-Present.
#
# Downloaded 07/18/2022
# - Files are split into 1 year per file.
#
# EXAMPLE USAGE:
# >> import glob
# >> import pandas as pd
# >> folder = "Data/Chicago/"
# >> crime_files = sorted(glob.glob(folder+"*.csv"))
# >> df = pd.concat([pd.read_csv(f) for f in crime_files])

# %% [markdown]
# ## Confirmation

# %% [markdown]
# - Follow the example usage above to test if your files were created successfully.

# %%
# get list of files from folder
crime_files = sorted(glob.glob(OUTPUT_FOLDER+"*.csv"))
df = pd.concat([pd.read_csv(f, nrows=5) for f in crime_files])
df
# Out:
#           ID                    Date            Primary Type  \
# 0    1314713  01/01/2001 01:00:00 PM                 ASSAULT
# 1    1311732  01/01/2001 01:00:00 PM  PUBLIC PEACE VIOLATION
# 2    1584605  01/01/2001 01:00:00 AM           OTHER OFFENSE
# 3    1317937  01/01/2001 01:00:00 AM                 BATTERY
# 4    1326041  01/01/2001 01:00:00 AM                 BATTERY
# ..       ...                     ...                     ...
# 0   12939189  01/01/2023 01:00:00 AM           OTHER OFFENSE
# 1   12938664  01/01/2023 01:00:00 AM     MOTOR VEHICLE THEFT
# 2   12943227  01/01/2023 01:00:00 AM                 ROBBERY
# 3   12942951  01/01/2023 01:00:00 AM      DECEPTIVE PRACTICE
# 4   12938987  01/01/2023 01:00:00 AM                 BATTERY
#
#                        Description       Location Description  Arrest  \
# 0   AGGRAVATED:KNIFE/CUTTING INSTR                  RESIDENCE    True
# 1                     ARSON THREAT                  RESIDENCE   False
# 2          HARASSMENT BY TELEPHONE                  RESIDENCE   False
# 3                           SIMPLE    RESIDENCE PORCH/HALLWAY   False
# 4                           SIMPLE                  RESIDENCE   False
# ..                             ...                        ...     ...
# 0            OTHER VEHICLE OFFENSE                     STREET   False
# 1                       AUTOMOBILE  CHA PARKING LOT / GROUNDS   False
# 2           STRONG ARM - NO WEAPON                  CTA TRAIN   False
# 3            ILLEGAL USE CASH CARD                  APARTMENT   False
# 4          DOMESTIC BATTERY SIMPLE     VEHICLE NON-COMMERCIAL   False
#
#     Domestic  Beat  District  Ward   Latitude  Longitude
# 0       True  1322      12.0   NaN  41.899521 -87.672220
# 1      False  1433      14.0   NaN  41.905753 -87.666380
# 2      False  1434      14.0   NaN  41.915639 -87.688701
# 3      False   334       3.0   NaN  41.762514 -87.565877
# 4      False  1624      16.0   NaN  41.957850 -87.749185
# ..       ...   ...       ...   ...        ...        ...
# 0       True   423       4.0   7.0  41.736726 -87.556955
# 1      False   533       5.0   9.0  41.656374 -87.607563
# 2      False  1132      11.0  24.0  41.873907 -87.725430
# 3      False   723       7.0  20.0  41.775359 -87.645890
# 4       True  1824      18.0   2.0  41.902187 -87.629934
#
# [115 rows x 12 columns]

# %%
years = df['Date'].map(lambda x: x.split()[0].split('/')[-1])
years.value_counts().sort_index()
# Out:
# 2001    5
# 2002    5
# 2003    5
# 2004    5
# 2005    5
# 2006    5
# 2007    5
# 2008    5
# 2009    5
# 2010    5
# 2011    5
# 2012    5
# 2013    5
# 2014    5
# 2015    5
# 2016    5
# 2017    5
# 2018    5
# 2019    5
# 2020    5
# 2021    5
# 2022    5
# 2023    5
# Name: Date, dtype: int64

# %% [markdown]
# ## Summary

# %% [markdown]
# - The chicago crime dataset has now been saved to your repository as csv files.
# - You should save your notebook, commit your work and push to GitHub using GitHub desktop.
