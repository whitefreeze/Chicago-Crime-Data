# %% [markdown]
# # Prepare Chicago Crime Data for a GitHub Repository

# %% [markdown]
# - Original Notebook Source: https://github.com/coding-dojo-data-science/preparing-chicago-crime-data
# - Updated 11/17/22

# %% [markdown]
# >- This notebook will process a "Crimes_-_2001_to_2023_processed.csv" crime file in your Downloads folder and save it as smaller .csv's in a new "Data/Chicago/" folder inside this notebook's folder/repo.

# %% [markdown]
# # INSTRUCTIONS

# %% [markdown]
# - 1) Export your Chicago Crime data to a CSV file. **The file is too big for a repository.**
#
# - 2) Once exported, change `RAW_FILE` variable below to match the filepath to the downloaded file.

# %% [markdown]
# ## 🚨 Set the correct `RAW_FILE` path

# %% [markdown]
# - The cell below will attempt to check your Downloads folder for any file with a name that contains "Crimes_-_2001_to_2023_processed".
#     - If you know the file path already, you can skip the next cell and just manually set the RAW_FILE variable in the following code cell.

# %%
## Run the cell below to attempt to programmatically find your crime file
import os,glob

## Getting the home folder from environment variables
home_folder = os.environ['HOME']
# print("- Your Home Folder is: " + home_folder)

## Check for downloads folder
if 'Downloads' in os.listdir(home_folder):
    
    
    # Print the Downloads folder path
    dl_folder = os.path.abspath(os.path.join(home_folder,'/Users/whitefreeze/Documents/GitHub/Chicago-Crime-Data/Data/Chicago'))
    print(f"- Your Downloads folder is '{dl_folder}/'\n")
    
    ## checking for crime files using glob
    crime_files = sorted(glob.glob(dl_folder+'/**/Crimes_-_2001_to_2023_processed*',recursive=True))
    
    # If more than 
    if len(crime_files)==1:
        RAW_FILE = crime_files[0]
        
    elif len(crime_files)>1:
        print('[i] The following files were found:')
        
        for i, fname in enumerate(crime_files):
            print(f"\tcrime_files[{i}] = '{fname}'")
        print(f'\n- Please fill in the RAW_FILE variable in the code cell below with the correct filepath.')

else:
    print(f'[!] Could not programmatically find your downloads folder.')
    print('- Try using Finder (on Mac) or File Explorer (Windows) to navigate to your Downloads folder.')
# Out:
# - Your Downloads folder is '/Users/whitefreeze/Documents/GitHub/Chicago-Crime-Data/Data/Chicago/'

# %% [markdown]
# <span style="color:red"> **IF THE CODE ABOVE DID NOT FIND YOUR DOWNLOADED FILE, UNCOMMENT AND CHANGE THE `"YOUR FILEPATH HERE"` VARIABLE ONLY IN THE CELL BELOW**

# %%
## (Required) MAKE SURE TO CHANGE THIS VARIABLE TO MATCH YOUR LOCAL FILE NAME
##RAW_FILE = r"YOUR FILEPATH HERE")

# %% [markdown]
# <span style="color:red"> **DO NOT CHANGE ANYTHING IN THE CELL BELOW**

# %%
## DO NOT CHANGE THIS CELL
if RAW_FILE == r"YOUR FILEPATH HERE":
	raise Exception("You must update the RAW_FILE variable in the previous cell to match your local filepath.")
	
RAW_FILE
# Out:
# '/Users/whitefreeze/Documents/GitHub/Chicago-Crime-Data/Data/Chicago/temp/Crimes_-_2001_to_2023_processed.csv'

# %%
## (Optional) SET THE FOLDER FOR FINAL FILES
OUTPUT_FOLDER = '/Users/whitefreeze/Documents/GitHub/Chicago-Crime-Data/Data/Chicago/'
os.makedirs(OUTPUT_FOLDER, exist_ok=True)

# %% [markdown]
# # 🔄 Full Workflow

# %% [markdown]
# - Now that your RAW_FILE variable is set either:
#     - On the toolbar, click on the Kernel menu > "Restart and Run All".
#     - OR click on this cell first, then on the toolbar click on the "Cell" menu > "Run All Below"

# %%
import pandas as pd

chicago_full = pd.read_csv(RAW_FILE)
chicago_full
# Out:
#                CrimeDateTime        ID        Primary Type  \
# 0        2001-01-01 00:00:00  13246664         SEX OFFENSE
# 1        2001-01-01 00:00:00   1369398  DECEPTIVE PRACTICE
# 2        2001-01-01 00:00:00   1322043     CRIMINAL DAMAGE
# 3        2001-01-01 00:00:00   1310724     CRIMINAL DAMAGE
# 4        2001-01-01 00:00:00   1318802               THEFT
# ...                      ...       ...                 ...
# 7974650  2023-12-31 23:50:00  13324881             BATTERY
# 7974651  2023-12-31 23:50:00  13327752               THEFT
# 7974652  2023-12-31 23:51:00  13324997             ASSAULT
# 7974653  2023-12-31 23:51:00  13325009             ASSAULT
# 7974654  2023-12-31 23:59:00  13327763     CRIMINAL DAMAGE
#
#                                  Description Location Description  Arrest  \
# 0                             NON-AGGRAVATED            RESIDENCE   False
# 1                                    FORGERY                OTHER   False
# 2                                TO PROPERTY            RESIDENCE   False
# 3                                TO PROPERTY            RESIDENCE   False
# 4                             $500 AND UNDER            RESIDENCE   False
# ...                                      ...                  ...     ...
# 7974650              DOMESTIC BATTERY SIMPLE            RESIDENCE   False
# 7974651                        FROM BUILDING        BAR OR TAVERN   False
# 7974652  AGGRAVATED - OTHER DANGEROUS WEAPON            APARTMENT   False
# 7974653  AGGRAVATED POLICE OFFICER - HANDGUN               STREET    True
# 7974654                           TO VEHICLE               STREET   False
#
#          Domestic  Beat  District   Latitude  Longitude
# 0           False  1723        17        NaN        NaN
# 1           False  1924        19  41.941360 -87.672218
# 2           False   825         8  41.782292 -87.684799
# 3           False   825         8  41.782030 -87.690891
# 4            True   532         5  41.667824 -87.622155
# ...           ...   ...       ...        ...        ...
# 7974650      True   923         9  41.800201 -87.691535
# 7974651     False   122         1  41.886816 -87.631524
# 7974652      True   624         6  41.754967 -87.602411
# 7974653     False   935         9  41.801584 -87.633177
# 7974654     False  1823        18  41.900698 -87.637330
#
# [7974655 rows x 11 columns]

# %%
# this cell can take up to 1 min to run
date_format = "%Y-%m-%d %H:%M:%S"

chicago_full['Datetime'] = pd.to_datetime(chicago_full['CrimeDateTime'], format=date_format)
chicago_full = chicago_full.sort_values('Datetime')
chicago_full
# Out:
#                CrimeDateTime        ID                Primary Type  \
# 0        2001-01-01 00:00:00  13246664                 SEX OFFENSE
# 124      2001-01-01 00:00:00   6742268  OFFENSE INVOLVING CHILDREN
# 125      2001-01-01 00:00:00   6483603                 SEX OFFENSE
# 126      2001-01-01 00:00:00   6040504  OFFENSE INVOLVING CHILDREN
# 127      2001-01-01 00:00:00   5926227                       THEFT
# ...                      ...       ...                         ...
# 7974649  2023-12-31 23:50:00  13324829                     BATTERY
# 7974651  2023-12-31 23:50:00  13327752                       THEFT
# 7974653  2023-12-31 23:51:00  13325009                     ASSAULT
# 7974652  2023-12-31 23:51:00  13324997                     ASSAULT
# 7974654  2023-12-31 23:59:00  13327763             CRIMINAL DAMAGE
#
#                                                Description  \
# 0                                           NON-AGGRAVATED
# 124                         AGG SEX ASSLT OF CHILD FAM MBR
# 125                                              PREDATORY
# 126                           CRIM SEX ABUSE BY FAM MEMBER
# 127                          FINANCIAL ID THEFT: OVER $300
# ...                                                    ...
# 7974649  AGGRAVATED P.O. - HANDS, FISTS, FEET, NO / MIN...
# 7974651                                      FROM BUILDING
# 7974653                AGGRAVATED POLICE OFFICER - HANDGUN
# 7974652                AGGRAVATED - OTHER DANGEROUS WEAPON
# 7974654                                         TO VEHICLE
#
#         Location Description  Arrest  Domestic  Beat  District   Latitude  \
# 0                  RESIDENCE   False     False  1723        17        NaN
# 124                RESIDENCE   False      True   612         6  41.755091
# 125                APARTMENT   False      True  2013        20  41.986230
# 126                RESIDENCE   False      True  1021        10  41.856707
# 127                RESIDENCE   False     False  2233        22  41.687651
# ...                      ...     ...       ...   ...       ...        ...
# 7974649               STREET   False     False  2532        25  41.906519
# 7974651        BAR OR TAVERN   False     False   122         1  41.886816
# 7974653               STREET    True     False   935         9  41.801584
# 7974652            APARTMENT   False      True   624         6  41.754967
# 7974654               STREET   False     False  1823        18  41.900698
#
#          Longitude            Datetime
# 0              NaN 2001-01-01 00:00:00
# 124     -87.652502 2001-01-01 00:00:00
# 125     -87.664563 2001-01-01 00:00:00
# 126     -87.712855 2001-01-01 00:00:00
# 127     -87.632719 2001-01-01 00:00:00
# ...            ...                 ...
# 7974649 -87.758360 2023-12-31 23:50:00
# 7974651 -87.631524 2023-12-31 23:50:00
# 7974653 -87.633177 2023-12-31 23:51:00
# 7974652 -87.602411 2023-12-31 23:51:00
# 7974654 -87.637330 2023-12-31 23:59:00
#
# [7974655 rows x 12 columns]

# %% [markdown]
# ## Separate the Full Dataset by Years

# %%
chicago_full['Datetime'].dt.year
# Out:
# 0          2001
# 124        2001
# 125        2001
# 126        2001
# 127        2001
#            ...
# 7974649    2023
# 7974651    2023
# 7974653    2023
# 7974652    2023
# 7974654    2023
# Name: Datetime, Length: 7974655, dtype: int64

# %%
# save the years for every crime
chicago_full["Year"] = chicago_full['Datetime'].dt.year.astype(str)
chicago_full["Year"].value_counts()
# Out:
# 2002    486813
# 2001    485903
# 2003    475987
# 2004    469428
# 2005    453776
# 2006    448183
# 2007    437090
# 2008    427193
# 2009    392835
# 2010    370525
# 2011    352006
# 2012    336333
# 2013    307552
# 2014    275811
# 2016    269865
# 2017    269138
# 2018    268950
# 2015    264823
# 2019    261411
# 2023    260541
# 2022    239152
# 2020    212306
# 2021    209034
# Name: Year, dtype: int64

# %%
chicago_full.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7974655 entries, 0 to 7974654
# Data columns (total 13 columns):
#  #   Column                Dtype
# ---  ------                -----
#  0   CrimeDateTime         object
#  1   ID                    int64
#  2   Primary Type          object
#  3   Description           object
#  4   Location Description  object
#  5   Arrest                bool
#  6   Domestic              bool
#  7   Beat                  int64
#  8   District              int64
#  9   Latitude              float64
#  10  Longitude             float64
#  11  Datetime              datetime64[ns]
#  12  Year                  object
# dtypes: bool(2), datetime64[ns](1), float64(2), int64(3), object(5)
# memory usage: 745.3+ MB

# %%
## Dropping unneeded columns to reduce file size
drop_cols = ["CrimeDateTime"]

# %%
# save final df
chicago_final = chicago_full.drop(columns=drop_cols)
chicago_final = chicago_final.set_index('Datetime')
chicago_final
# Out:
#                            ID                Primary Type  \
# Datetime
# 2001-01-01 00:00:00  13246664                 SEX OFFENSE
# 2001-01-01 00:00:00   6742268  OFFENSE INVOLVING CHILDREN
# 2001-01-01 00:00:00   6483603                 SEX OFFENSE
# 2001-01-01 00:00:00   6040504  OFFENSE INVOLVING CHILDREN
# 2001-01-01 00:00:00   5926227                       THEFT
# ...                       ...                         ...
# 2023-12-31 23:50:00  13324829                     BATTERY
# 2023-12-31 23:50:00  13327752                       THEFT
# 2023-12-31 23:51:00  13325009                     ASSAULT
# 2023-12-31 23:51:00  13324997                     ASSAULT
# 2023-12-31 23:59:00  13327763             CRIMINAL DAMAGE
#
#                                                            Description  \
# Datetime
# 2001-01-01 00:00:00                                     NON-AGGRAVATED
# 2001-01-01 00:00:00                     AGG SEX ASSLT OF CHILD FAM MBR
# 2001-01-01 00:00:00                                          PREDATORY
# 2001-01-01 00:00:00                       CRIM SEX ABUSE BY FAM MEMBER
# 2001-01-01 00:00:00                      FINANCIAL ID THEFT: OVER $300
# ...                                                                ...
# 2023-12-31 23:50:00  AGGRAVATED P.O. - HANDS, FISTS, FEET, NO / MIN...
# 2023-12-31 23:50:00                                      FROM BUILDING
# 2023-12-31 23:51:00                AGGRAVATED POLICE OFFICER - HANDGUN
# 2023-12-31 23:51:00                AGGRAVATED - OTHER DANGEROUS WEAPON
# 2023-12-31 23:59:00                                         TO VEHICLE
#
#                     Location Description  Arrest  Domestic  Beat  District  \
# Datetime
# 2001-01-01 00:00:00            RESIDENCE   False     False  1723        17
# 2001-01-01 00:00:00            RESIDENCE   False      True   612         6
# 2001-01-01 00:00:00            APARTMENT   False      True  2013        20
# 2001-01-01 00:00:00            RESIDENCE   False      True  1021        10
# 2001-01-01 00:00:00            RESIDENCE   False     False  2233        22
# ...                                  ...     ...       ...   ...       ...
# 2023-12-31 23:50:00               STREET   False     False  2532        25
# 2023-12-31 23:50:00        BAR OR TAVERN   False     False   122         1
# 2023-12-31 23:51:00               STREET    True     False   935         9
# 2023-12-31 23:51:00            APARTMENT   False      True   624         6
# 2023-12-31 23:59:00               STREET   False     False  1823        18
#
#                       Latitude  Longitude  Year
# Datetime
# 2001-01-01 00:00:00        NaN        NaN  2001
# 2001-01-01 00:00:00  41.755091 -87.652502  2001
# 2001-01-01 00:00:00  41.986230 -87.664563  2001
# 2001-01-01 00:00:00  41.856707 -87.712855  2001
# 2001-01-01 00:00:00  41.687651 -87.632719  2001
# ...                        ...        ...   ...
# 2023-12-31 23:50:00  41.906519 -87.758360  2023
# 2023-12-31 23:50:00  41.886816 -87.631524  2023
# 2023-12-31 23:51:00  41.801584 -87.633177  2023
# 2023-12-31 23:51:00  41.754967 -87.602411  2023
# 2023-12-31 23:59:00  41.900698 -87.637330  2023
#
# [7974655 rows x 11 columns]

# %%
# unique # of year bins
year_bins = chicago_final['Year'].astype(str).unique()
year_bins
# Out:
# array(['2001', '2002', '2003', '2004', '2005', '2006', '2007', '2008',
#        '2009', '2010', '2011', '2012', '2013', '2014', '2015', '2016',
#        '2017', '2018', '2019', '2020', '2021', '2022', '2023'],
#       dtype=object)

# %%
FINAL_DROP = ['Year']

# %%
## set save location 

os.makedirs(OUTPUT_FOLDER, exist_ok=True)
print(f"[i] Saving .csv's to {OUTPUT_FOLDER}")
## loop through years
for year in year_bins:
    
    ## save temp slices of dfs to save.
    temp_df = chicago_final.loc[year]
    temp_df = temp_df.sort_index()
    #temp_df = temp_df.reset_index(drop=True)
    temp_df = temp_df.drop(columns=FINAL_DROP)

    # save as csv to output folder
    fname_temp = f"{OUTPUT_FOLDER}Chicago-Crime_{year}.csv"#.gz
    temp_df.to_csv(fname_temp,index=True)

    print(f"- Successfully saved {fname_temp}")
# Out:
# [i] Saving .csv's to /Users/whitefreeze/Documents/GitHub/Chicago-Crime-Data/Data/Chicago/
# - Successfully saved /Users/whitefreeze/Documents/GitHub/Chicago-Crime-Data/Data/Chicago/Chicago-Crime_2001.csv
# - Successfully saved /Users/whitefreeze/Documents/GitHub/Chicago-Crime-Data/Data/Chicago/Chicago-Crime_2002.csv
# - Successfully saved /Users/whitefreeze/Documents/GitHub/Chicago-Crime-Data/Data/Chicago/Chicago-Crime_2003.csv
# - Successfully saved /Users/whitefreeze/Documents/GitHub/Chicago-Crime-Data/Data/Chicago/Chicago-Crime_2004.csv
# - Successfully saved /Users/whitefreeze/Documents/GitHub/Chicago-Crime-Data/Data/Chicago/Chicago-Crime_2005.csv
# - Successfully saved /Users/whitefreeze/Documents/GitHub/Chicago-Crime-Data/Data/Chicago/Chicago-Crime_2006.csv
# - Successfully saved /Users/whitefreeze/Documents/GitHub/Chicago-Crime-Data/Data/Chicago/Chicago-Crime_2007.csv
# - Successfully saved /Users/whitefreeze/Documents/GitHub/Chicago-Crime-Data/Data/Chicago/Chicago-Crime_2008.csv
# - Successfully saved /Users/whitefreeze/Documents/GitHub/Chicago-Crime-Data/Data/Chicago/Chicago-Crime_2009.csv
# - Successfully saved /Users/whitefreeze/Documents/GitHub/Chicago-Crime-Data/Data/Chicago/Chicago-Crime_2010.csv
# - Successfully saved /Users/whitefreeze/Documents/GitHub/Chicago-Crime-Data/Data/Chicago/Chicago-Crime_2011.csv
# - Successfully saved /Users/whitefreeze/Documents/GitHub/Chicago-Crime-Data/Data/Chicago/Chicago-Crime_2012.csv
# - Successfully saved /Users/whitefreeze/Documents/GitHub/Chicago-Crime-Data/Data/Chicago/Chicago-Crime_2013.csv
# - Successfully saved /Users/whitefreeze/Documents/GitHub/Chicago-Crime-Data/Data/Chicago/Chicago-Crime_2014.csv
# - Successfully saved /Users/whitefreeze/Documents/GitHub/Chicago-Crime-Data/Data/Chicago/Chicago-Crime_2015.csv
# - Successfully saved /Users/whitefreeze/Documents/GitHub/Chicago-Crime-Data/Data/Chicago/Chicago-Crime_2016.csv
# - Successfully saved /Users/whitefreeze/Documents/GitHub/Chicago-Crime-Data/Data/Chicago/Chicago-Crime_2017.csv
# - Successfully saved /Users/whitefreeze/Documents/GitHub/Chicago-Crime-Data/Data/Chicago/Chicago-Crime_2018.csv
# - Successfully saved /Users/whitefreeze/Documents/GitHub/Chicago-Crime-Data/Data/Chicago/Chicago-Crime_2019.csv
# - Successfully saved /Users/whitefreeze/Documents/GitHub/Chicago-Crime-Data/Data/Chicago/Chicago-Crime_2020.csv
# - Successfully saved /Users/whitefreeze/Documents/GitHub/Chicago-Crime-Data/Data/Chicago/Chicago-Crime_2021.csv
# - Successfully saved /Users/whitefreeze/Documents/GitHub/Chicago-Crime-Data/Data/Chicago/Chicago-Crime_2022.csv
# - Successfully saved /Users/whitefreeze/Documents/GitHub/Chicago-Crime-Data/Data/Chicago/Chicago-Crime_2023.csv

# %%
saved_files = sorted(glob.glob(OUTPUT_FOLDER+'*.*csv'))
saved_files
# Out:
# ['/Users/whitefreeze/Documents/GitHub/Chicago-Crime-Data/Data/Chicago/Chicago-Crime_2001.csv',
#  '/Users/whitefreeze/Documents/GitHub/Chicago-Crime-Data/Data/Chicago/Chicago-Crime_2002.csv',
#  '/Users/whitefreeze/Documents/GitHub/Chicago-Crime-Data/Data/Chicago/Chicago-Crime_2003.csv',
#  '/Users/whitefreeze/Documents/GitHub/Chicago-Crime-Data/Data/Chicago/Chicago-Crime_2004.csv',
#  '/Users/whitefreeze/Documents/GitHub/Chicago-Crime-Data/Data/Chicago/Chicago-Crime_2005.csv',
#  '/Users/whitefreeze/Documents/GitHub/Chicago-Crime-Data/Data/Chicago/Chicago-Crime_2006.csv',
#  '/Users/whitefreeze/Documents/GitHub/Chicago-Crime-Data/Data/Chicago/Chicago-Crime_2007.csv',
#  '/Users/whitefreeze/Documents/GitHub/Chicago-Crime-Data/Data/Chicago/Chicago-Crime_2008.csv',
#  '/Users/whitefreeze/Documents/GitHub/Chicago-Crime-Data/Data/Chicago/Chicago-Crime_2009.csv',
#  '/Users/whitefreeze/Documents/GitHub/Chicago-Crime-Data/Data/Chicago/Chicago-Crime_2010.csv',
#  '/Users/whitefreeze/Documents/GitHub/Chicago-Crime-Data/Data/Chicago/Chicago-Crime_2011.csv',
#  '/Users/whitefreeze/Documents/GitHub/Chicago-Crime-Data/Data/Chicago/Chicago-Crime_2012.csv',
#  '/Users/whitefreeze/Documents/GitHub/Chicago-Crime-Data/Data/Chicago/Chicago-Crime_2013.csv',
#  '/Users/whitefreeze/Documents/GitHub/Chicago-Crime-Data/Data/Chicago/Chicago-Crime_2014.csv',
#  '/Users/whitefreeze/Documents/GitHub/Chicago-Crime-Data/Data/Chicago/Chicago-Crime_2015.csv',
#  '/Users/whitefreeze/Documents/GitHub/Chicago-Crime-Data/Data/Chicago/Chicago-Crime_2016.csv',
#  '/Users/whitefreeze/Documents/GitHub/Chicago-Crime-Data/Data/Chicago/Chicago-Crime_2017.csv',
#  '/Users/whitefreeze/Documents/GitHub/Chicago-Crime-Data/Data/Chicago/Chicago-Crime_2018.csv',
#  '/Users/whitefreeze/Documents/GitHub/Chicago-Crime-Data/Data/Chicago/Chicago-Crime_2019.csv',
#  '/Users/whitefreeze/Documents/GitHub/Chicago-Crime-Data/Data/Chicago/Chicago-Crime_2020.csv',
#  '/Users/whitefreeze/Documents/GitHub/Chicago-Crime-Data/Data/Chicago/Chicago-Crime_2021.csv',
#  '/Users/whitefreeze/Documents/GitHub/Chicago-Crime-Data/Data/Chicago/Chicago-Crime_2022.csv',
#  '/Users/whitefreeze/Documents/GitHub/Chicago-Crime-Data/Data/Chicago/Chicago-Crime_2023.csv']

# %%
## create a README.txt for the zip files
readme = """Source URL: 
- https://data.cityofchicago.org/Public-Safety/Crimes-2001-to-Present/ijzp-q8t2
- Filtered for years 2000-Present.

Downloaded 01/01/2024
- Files are split into 1 year per file.

EXAMPLE USAGE:
>> import glob
>> import pandas as pd
>> folder = "Data/Chicago/"
>> crime_files = sorted(glob.glob(folder+"*.csv"))
>> df = pd.concat([pd.read_csv(f) for f in crime_files])
"""
print(readme)


with open(f"{OUTPUT_FOLDER}README.txt",'w') as f:
    f.write(readme)
# Out:
# Source URL:
# - https://data.cityofchicago.org/Public-Safety/Crimes-2001-to-Present/ijzp-q8t2
# - Filtered for years 2000-Present.
#
# Downloaded 01/01/2024
# - Files are split into 1 year per file.
#
# EXAMPLE USAGE:
# >> import glob
# >> import pandas as pd
# >> folder = "Data/Chicago/"
# >> crime_files = sorted(glob.glob(folder+"*.csv"))
# >> df = pd.concat([pd.read_csv(f) for f in crime_files])

# %% [markdown]
# ## Confirmation

# %% [markdown]
# - Follow the example usage above to test if your files were created successfully.

# %%
# get list of files from folder
crime_files = sorted(glob.glob(OUTPUT_FOLDER+"*.csv"))
df = pd.concat([pd.read_csv(f, nrows=5) for f in crime_files])
df
# Out:
#                Datetime        ID                Primary Type  \
# 0   2001-01-01 00:00:00  13246664                 SEX OFFENSE
# 1   2001-01-01 00:00:00   6742268  OFFENSE INVOLVING CHILDREN
# 2   2001-01-01 00:00:00   6483603                 SEX OFFENSE
# 3   2001-01-01 00:00:00   6040504  OFFENSE INVOLVING CHILDREN
# 4   2001-01-01 00:00:00   5926227                       THEFT
# ..                  ...       ...                         ...
# 0   2023-01-01 00:00:00  12989036                    BURGLARY
# 1   2023-01-01 00:00:00  12938946             CRIMINAL DAMAGE
# 2   2023-01-01 00:00:00  12938519             CRIMINAL DAMAGE
# 3   2023-01-01 00:00:00  12938498                     BATTERY
# 4   2023-01-01 00:00:00  12984848          DECEPTIVE PRACTICE
#
#                            Description            Location Description  \
# 0                       NON-AGGRAVATED                       RESIDENCE
# 1       AGG SEX ASSLT OF CHILD FAM MBR                       RESIDENCE
# 2                            PREDATORY                       APARTMENT
# 3         CRIM SEX ABUSE BY FAM MEMBER                       RESIDENCE
# 4        FINANCIAL ID THEFT: OVER $300                       RESIDENCE
# ..                                 ...                             ...
# 0                       UNLAWFUL ENTRY                       APARTMENT
# 1                          TO PROPERTY                       RESIDENCE
# 2                           TO VEHICLE  GOVERNMENT BUILDING / PROPERTY
# 3              DOMESTIC BATTERY SIMPLE                       APARTMENT
# 4   ATTEMPT - FINANCIAL IDENTITY THEFT                       RESIDENCE
#
#     Arrest  Domestic  Beat  District   Latitude  Longitude
# 0    False     False  1723        17        NaN        NaN
# 1    False      True   612         6  41.755091 -87.652502
# 2    False      True  2013        20  41.986230 -87.664563
# 3    False      True  1021        10  41.856707 -87.712855
# 4    False     False  2233        22  41.687651 -87.632719
# ..     ...       ...   ...       ...        ...        ...
# 0    False     False  1832        18  41.900547 -87.633632
# 1    False     False  2233        22  41.686490 -87.638563
# 2    False     False   621         6  41.751928 -87.644077
# 3    False      True   624         6  41.750371 -87.599099
# 4    False     False  2233        22  41.699691 -87.638235
#
# [115 rows x 11 columns]

# %%
years = df['Datetime'].map(lambda x: x.split()[0].split('/')[-1])
years.value_counts().sort_index()
# Out:
# 2001-01-01    5
# 2002-01-01    5
# 2003-01-01    5
# 2004-01-01    5
# 2005-01-01    5
# 2006-01-01    5
# 2007-01-01    5
# 2008-01-01    5
# 2009-01-01    5
# 2010-01-01    5
# 2011-01-01    5
# 2012-01-01    5
# 2013-01-01    5
# 2014-01-01    5
# 2015-01-01    5
# 2016-01-01    5
# 2017-01-01    5
# 2018-01-01    5
# 2019-01-01    5
# 2020-01-01    5
# 2021-01-01    5
# 2022-01-01    5
# 2023-01-01    5
# Name: Datetime, dtype: int64

# %% [markdown]
# ## Summary

# %% [markdown]
# - The chicago crime dataset has now been saved to your repository as csv files.
# - You should save your notebook, commit your work and push to GitHub using GitHub desktop.
